# %% [markdown]
# # Plot_FARGO Demo

# %% [markdown]
# First of all we need to tell our system where plot_fargo is

# %%
import sys
sys.path.append("/Users/aaronschneider/fargo3d-1.2/plot_fargo") #can work from anywhere

# %% [markdown]
# Together with matplotlib we then import the Plot_FARGO class

# %%
import matplotlib.pyplot as plt
from plot_fargo import Plot_FARGO
# %matplotlib inline

# %% [markdown]
# Now we want to demonstrate the results using the default fargo setup

# %%
pl = Plot_FARGO("/Users/aaronschneider/fargo3d-1.2", "fargo")
fig, ax = pl.plot_2D(40, tp = "gasdens", log10= True, polar=True)

# %% [markdown]
# We could also still do some work on our plot (e.q. change the title)

# %%
pl = Plot_FARGO("/Users/aaronschneider/fargo3d-1.2", "fargo")
fig, ax = pl.plot_2D(40, tp = "gasdens", log10= True, polar=True)
ax.set_title('Hallo\n')
plt.show()

# %% [markdown]
# Creating a video is done very similar:
#
# (needs the folders "single_frames", "videos" in the working directory)

# %%
pl.plot_2D_video(filename= "fargo_test", tp = "gasdens", log10= False, polar=True)
